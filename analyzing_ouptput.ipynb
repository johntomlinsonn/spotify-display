# %%
import json
import os


with open('currently_playing.json', 'r') as f:
    results = json.load(f)

results = dict(results)
results['item']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Gso3d4CscCijv0lmajZWs'},
#     'href': 'https://api.spotify.com/v1/artists/4Gso3d4CscCijv0lmajZWs',
#     'id': '4Gso3d4CscCijv0lmajZWs',
#     'name': 'Don Toliver',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Gso3d4CscCijv0lmajZWs'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/131x9G87mD0hP0hGZc9qYN'},
#   'href': 'https://api.spotify.com/v1/albums/131x9G87mD0hP0hGZc9qYN',
#   'id': '131x9G87mD0hP0hGZc9qYN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27325c28f3c9fbdbab1a88dd619',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0225c28f3c9fbdbab1a88dd619',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485125c28f3c9fbdbab1a88dd619',
#     'width': 64}],
#   'name': 'OCTANE',
#   'release_date': '2026-01-30',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:131x9G87mD0hP0hGZc9qYN'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Gso3d4CscCijv0lmajZWs'},
#    'href': 'https://api.spotify.com/v1/artists/4Gso3d4CscCijv0lmajZWs',
#    'id': '4Gso3d4CscCijv0lmajZWs',
#    'name': 'Don Toliver',
#    'type': 'artist',
#    'uri': 'spotify:artist:4Gso3d4CscCijv0lmajZWs'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qiHUAX7zY4Qnjx8TNUzVx'},
#    'href': 'https://api.spotify.com/v1/artists/3qiHUAX7zY4Qnjx8TNUzVx',
#    'id': '3qiHUAX7zY4Qnjx8TNUzVx',
#    'name': 'Yeat',
#    'type': 'artist',
#    'uri': 'spotify:artist:3qiHUAX7zY4Qnjx8TNUzVx'}],
#  'disc_number': 1,
#  'duration_ms': 146801,
#  'explicit': True,
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2Ejyg4CavumEr7lFUkk9aF'},
#  'href': 'https://api.spotify.com/v1/tracks/2Ejyg4CavumEr7lFUkk9aF',
#  'id': '2Ejyg4CavumEr7lFUkk9aF',
#  'is_local': False,
#  'name': 'Rendezvous (feat. Yeat)',
#  'preview_url': None,
#  'track_number': 3,
#  'type': 'track',
#  'uri': 'spotify:track:2Ejyg4CavumEr7lFUkk9aF'}

# %% [markdown]
# Getting artists

# %%
for artist in results['item']['artists']:
    print(artist['name'])
# Out:
# Don Toliver
# Yeat

# %% [markdown]
# Getting name

# %%
results['item']['name']
# Out:
# 'Rendezvous (feat. Yeat)'

# %%
image_link = results['item']['album']['images'][0]['url']

# %%
import requests
from io import BytesIO
from PIL import Image

response = requests.get(image_link)
img = Image.open(BytesIO(response.content))
img.show()
